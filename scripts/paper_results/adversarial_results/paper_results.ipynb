# %%
from pathlib import Path
import numpy as np
import os
import shutil
# run adversarial that trained with ladder training

models = {
    "ladder" : Path("/home/isaacp/sharedrepos/IsaacLab-HARL/scripts/reinforcement_learning/harl/"+
                  "results/isaaclab/leatherback-Sumo-Direct-MA-Stage2-v0/happo_adv/"+
                  "leatherback_ladder_training/seed-00001-2025-08-29-15-44-20/models/checkpoints"),
    "leapfrog" : Path("/home/isaacp/sharedrepos/IsaacLab-HARL/scripts/reinforcement_learning/"+
                "harl/results/isaaclab/leatherback-Sumo-Direct-MA-Stage2-v0/happo_adv/"+
                "leatherback_leapfrog_training/seed-00001-2025-08-29-22-27-04/models/checkpoints"),
    "parallel" : Path("/home/isaacp/sharedrepos/IsaacLab-HARL/scripts/reinforcement_learning/harl"+
                "/results/isaaclab/leatherback-Sumo-Direct-MA-Stage2-v0/happo_adv/"+
                "leatherback_parallel_training/seed-00001-2025-08-29-19-06-53/models/checkpoints")
}

checkpoint_1_folder="episode_1"
results = {}

try:
    for key, models_dir in models.items():
        for curr_folder in sorted(os.listdir(models_dir),
                                key=lambda x: int(x.split("_")[-1]) if "episode" in x else -1):
            if "episode" in curr_folder:
                episode_num = int(curr_folder.split("_")[-1])
                if "episode_num" not in results:
                    results["episode_num"] = {}
                if key not in results["episode_num"]:
                    results["episode_num"][key] = []
                results["episode_num"][key].append(episode_num)

                checkpoint_1_path=models_dir / checkpoint_1_folder
                curr_checkpoint_path=models_dir / curr_folder

                new_checkpoint_path = models_dir / "curr_checkpoint"

                # we take the policies from the first checkpoint and compare them against the current policies
                os.makedirs(new_checkpoint_path, exist_ok=True)
                shutil.copy(checkpoint_1_path / "actor_agent_robot_2.pt", new_checkpoint_path / "actor_agent_robot_2.pt")
                shutil.copy(checkpoint_1_path / "actor_agent_robot_3.pt", new_checkpoint_path / "actor_agent_robot_3.pt")
                shutil.copy(curr_checkpoint_path / "actor_agent_robot_0.pt", new_checkpoint_path / "actor_agent_robot_0.pt")
                shutil.copy(curr_checkpoint_path / "actor_agent_robot_1.pt", new_checkpoint_path / "actor_agent_robot_1.pt")

                npz_save_path = "./ladder_training_results.npz"

                # !python ./get_adversarial_results.py \
                    --num_envs 100 \
                    --algo "happo_adv" \
                    --task "leatherback-Sumo-Direct-MA-Stage2-v0" \
                    --seed 1 \
                    --num_env_steps 3_100_000 \
                    --dir {new_checkpoint_path} \
                    --save_path {npz_save_path} \
                    --debug \
                    --headless

                res = np.load(npz_save_path)
                for k, v in res.items():
                    if k not in results:
                        results[k] = {}
                    if key not in results[k]:
                        results[k][key] = []
                    results[k][key].append(v.item())
except Exception as e:
    print(f"An error occurred: {e}")
finally:
    if 'new_checkpoint_path' in locals() and os.path.exists(new_checkpoint_path):
        shutil.rmtree(new_checkpoint_path)
    if 'npz_save_path' in locals() and os.path.exists(npz_save_path):
        os.remove(npz_save_path)
# Out:
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: /home/isaacp/sharedrepos/IsaacLab-HARL/apps/isaaclab.python.headless.kit
# [Warning] [simulation_app.simulation_app] Modules: ['omni.kit_app'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [simulation_app.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Loading user config located at: '/home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/data/Kit/Isaac-Sim/4.5/user.config.json'
# [Info] [carb] Logging to file: /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/logs/Kit/Isaac-Sim/4.5/kit_20250902_172113.log
# 2025-09-02 23:21:13 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# 2025-09-02 23:21:13 s] [Warning] [omni.ext.plugin] [ext: rendering_modes] Extensions config 'extension.toml' doesn't exist '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes' or '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes/config'
# 2025-09-02 23:21:14 s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2025-09-02 23:21:14 s] [Warning] [omni.datastore] OmniHub is inaccessible
# 2025-09-02 23:21:14 s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-Humanoid-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-H1-Velocity-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-09-02 23:21:18 [4,493ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
# 2025-09-02 23:21:18 [4,493ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.144.03    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24564   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e9f2bf62.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Unknown (RADV RAPHAEL_MEND.. |        |     | 21483   MB | 1002      | 0          |
# |     |                                  |        |     |            | 164e      | 00000000.. |
# |     |                                  |        |     |            | d         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-65-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD Ryzen 9 7950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 63426 | Free Memory: 50874
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# 2025-09-02 23:21:19 [5,855ms] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# 2025-09-02 23:21:19 [5,855ms] [Warning] [gpu.foundation.plugin] Detected IOMMU is enabled. Running CUDA peer-to-peer bandwidth and latency validation.
# Unidirectional P2P=Enabled Bandwidth (P2P Writes) Matrix (GB/s)
#    D\D     0
#      0 912.68
# P2P=Enabled Latency (P2P Writes) Matrix (us)
#    GPU     0
#      0   1.37
#
#    CPU     0
#      0   1.99
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# [INFO]: Parsing configuration from: <class 'isaaclab_tasks.direct.leatherback.leatherback_sumo_ma_stage2.LeatherbackSumoMAStage2EnvCfg'>
# [INFO]: Parsing configuration from: /home/isaacp/sharedrepos/IsaacLab-HARL/source/isaaclab_tasks/isaaclab_tasks/direct/leatherback/agents/harl_happo_adv_cfg.yaml
# choose to use gpu...
# 2025-09-02 23:21:20 [6,364ms] [Warning] [isaaclab.envs.direct_marl_env] Seed not set for the environment. The environment creation may not be deterministic.
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : None
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.333662 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 100
# 	Environment spacing   : 12
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : True
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# 2025-09-02 23:21:21 [7,180ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,180ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,182ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,182ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,240ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,240ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,241ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,242ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,248ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,248ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,249ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,249ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,255ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,255ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:21:21 [7,256ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:21:21 [7,256ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# [INFO]: Time taken for simulation start : 0.574367 seconds
# [INFO]: Completed setting up the environment...
# 2025-09-02 23:21:21 [7,319ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPreviewSurface.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,319ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdUVTexture.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,319ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,319ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float2.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float3.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float4.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_int.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_string.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_normal.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_point.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_vector.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_matrix.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:21:21 [7,320ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdTransform2d.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# share_observation_space:  {'team_0': Box(-inf, inf, (28,), float32), 'team_1': Box(-inf, inf, (28,), float32)}
# observation_space:  {'team_0': {'robot_0': Box(-inf, inf, (14,), float32), 'robot_1': Box(-inf, inf, (14,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (14,), float32), 'robot_3': Box(-inf, inf, (14,), float32)}}
# action_space:  {'team_0': {'robot_0': Box(-inf, inf, (2,), float32), 'robot_1': Box(-inf, inf, (2,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (2,), float32), 'robot_3': Box(-inf, inf, (2,), float32)}}
# /home/isaacp/sharedrepos/HARL/harl/runners/on_policy_base_runner_adversarial.py:948: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(actor_path)
# Playing: 3100200it [02:04, 24981.75it/s]
# {'Episode_Reward/team_0_push_out_reward': 0.0009076835996407361,
#  'Episode_Reward/team_1_push_out_reward': -0.002220660733514046,
#  'team0_win_percentage': 0.4687022900763359,
#  'team1_win_percentage': 0.46564885496183206}
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: /home/isaacp/sharedrepos/IsaacLab-HARL/apps/isaaclab.python.headless.kit
# [Warning] [simulation_app.simulation_app] Modules: ['omni.kit_app'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [simulation_app.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Loading user config located at: '/home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/data/Kit/Isaac-Sim/4.5/user.config.json'
# [Info] [carb] Logging to file: /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/logs/Kit/Isaac-Sim/4.5/kit_20250902_172327.log
# 2025-09-02 23:23:27 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# 2025-09-02 23:23:27 s] [Warning] [omni.ext.plugin] [ext: rendering_modes] Extensions config 'extension.toml' doesn't exist '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes' or '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes/config'
# 2025-09-02 23:23:27 s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2025-09-02 23:23:27 s] [Warning] [omni.datastore] OmniHub is inaccessible
# 2025-09-02 23:23:28 s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-Humanoid-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-H1-Velocity-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-09-02 23:23:32 [4,480ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
# 2025-09-02 23:23:32 [4,480ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.144.03    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24564   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e9f2bf62.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Unknown (RADV RAPHAEL_MEND.. |        |     | 21483   MB | 1002      | 0          |
# |     |                                  |        |     |            | 164e      | 00000000.. |
# |     |                                  |        |     |            | d         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-65-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD Ryzen 9 7950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 63426 | Free Memory: 50754
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# 2025-09-02 23:23:33 [5,776ms] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# 2025-09-02 23:23:33 [5,776ms] [Warning] [gpu.foundation.plugin] Detected IOMMU is enabled. Running CUDA peer-to-peer bandwidth and latency validation.
# Unidirectional P2P=Enabled Bandwidth (P2P Writes) Matrix (GB/s)
#    D\D     0
#      0 912.14
# P2P=Enabled Latency (P2P Writes) Matrix (us)
#    GPU     0
#      0   1.38
#
#    CPU     0
#      0   1.42
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# [INFO]: Parsing configuration from: <class 'isaaclab_tasks.direct.leatherback.leatherback_sumo_ma_stage2.LeatherbackSumoMAStage2EnvCfg'>
# [INFO]: Parsing configuration from: /home/isaacp/sharedrepos/IsaacLab-HARL/source/isaaclab_tasks/isaaclab_tasks/direct/leatherback/agents/harl_happo_adv_cfg.yaml
# choose to use gpu...
# 2025-09-02 23:23:33 [6,287ms] [Warning] [isaaclab.envs.direct_marl_env] Seed not set for the environment. The environment creation may not be deterministic.
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : None
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.344337 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 100
# 	Environment spacing   : 12
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : True
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# 2025-09-02 23:23:34 [7,108ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,108ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,110ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,110ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,164ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,164ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,165ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,165ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,171ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,171ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,171ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,171ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,177ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,177ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:23:34 [7,178ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:23:34 [7,178ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# [INFO]: Time taken for simulation start : 0.559628 seconds
# [INFO]: Completed setting up the environment...
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPreviewSurface.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdUVTexture.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float2.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float3.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float4.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_int.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_string.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,238ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_normal.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,239ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_point.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,239ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_vector.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,239ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_matrix.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:23:34 [7,239ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdTransform2d.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# share_observation_space:  {'team_0': Box(-inf, inf, (28,), float32), 'team_1': Box(-inf, inf, (28,), float32)}
# observation_space:  {'team_0': {'robot_0': Box(-inf, inf, (14,), float32), 'robot_1': Box(-inf, inf, (14,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (14,), float32), 'robot_3': Box(-inf, inf, (14,), float32)}}
# action_space:  {'team_0': {'robot_0': Box(-inf, inf, (2,), float32), 'robot_1': Box(-inf, inf, (2,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (2,), float32), 'robot_3': Box(-inf, inf, (2,), float32)}}
# /home/isaacp/sharedrepos/HARL/harl/runners/on_policy_base_runner_adversarial.py:948: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(actor_path)
# Playing: 3100200it [01:59, 25867.73it/s]
# {'Episode_Reward/team_0_push_out_reward': -0.0009556286540096519,
#  'Episode_Reward/team_1_push_out_reward': -0.00028064213586093367,
#  'team0_win_percentage': 0.4934865900383142,
#  'team1_win_percentage': 0.4559386973180077}
# [INFO][AppLauncher]: Using device: cuda:0
# [INFO][AppLauncher]: Loading experience file: /home/isaacp/sharedrepos/IsaacLab-HARL/apps/isaaclab.python.headless.kit
# [Warning] [simulation_app.simulation_app] Modules: ['omni.kit_app'] were loaded before SimulationApp was started and might not be loaded correctly.
# [Warning] [simulation_app.simulation_app] Please check to make sure no extra omniverse or pxr modules are imported before the call to SimulationApp(...)
# Loading user config located at: '/home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/data/Kit/Isaac-Sim/4.5/user.config.json'
# [Info] [carb] Logging to file: /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/omni/logs/Kit/Isaac-Sim/4.5/kit_20250902_172537.log
# 2025-09-02 23:25:37 s] [Warning] [omni.kit.app.plugin] No crash reporter present, dumps uploading isn't available.
# 2025-09-02 23:25:37 s] [Warning] [omni.ext.plugin] [ext: rendering_modes] Extensions config 'extension.toml' doesn't exist '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes' or '/home/isaacp/sharedrepos/IsaacLab-HARL/apps/rendering_modes/config'
# 2025-09-02 23:25:37 s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2025-09-02 23:25:37 s] [Warning] [omni.datastore] OmniHub is inaccessible
# 2025-09-02 23:25:37 s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-Humanoid-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-H1-Velocity-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-09-02 23:25:41 [4,382ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
# 2025-09-02 23:25:41 [4,382ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.144.03    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24564   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e9f2bf62.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Unknown (RADV RAPHAEL_MEND.. |        |     | 21483   MB | 1002      | 0          |
# |     |                                  |        |     |            | 164e      | 00000000.. |
# |     |                                  |        |     |            | d         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-65-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD Ryzen 9 7950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 63426 | Free Memory: 50051
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# 2025-09-02 23:25:42 [5,795ms] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# 2025-09-02 23:25:42 [5,795ms] [Warning] [gpu.foundation.plugin] Detected IOMMU is enabled. Running CUDA peer-to-peer bandwidth and latency validation.
# Unidirectional P2P=Enabled Bandwidth (P2P Writes) Matrix (GB/s)
#    D\D     0
#      0 913.74
# P2P=Enabled Latency (P2P Writes) Matrix (us)
#    GPU     0
#      0   1.38
#
#    CPU     0
#      0   1.45
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# [INFO]: Parsing configuration from: <class 'isaaclab_tasks.direct.leatherback.leatherback_sumo_ma_stage2.LeatherbackSumoMAStage2EnvCfg'>
# [INFO]: Parsing configuration from: /home/isaacp/sharedrepos/IsaacLab-HARL/source/isaaclab_tasks/isaaclab_tasks/direct/leatherback/agents/harl_happo_adv_cfg.yaml
# choose to use gpu...
# 2025-09-02 23:25:43 [6,290ms] [Warning] [isaaclab.envs.direct_marl_env] Seed not set for the environment. The environment creation may not be deterministic.
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : None
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.355254 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 100
# 	Environment spacing   : 12
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : True
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# 2025-09-02 23:25:44 [7,116ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,116ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,117ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,117ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,161ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,161ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,162ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,162ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,168ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,168ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,168ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,168ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,174ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,174ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-02 23:25:44 [7,174ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-02 23:25:44 [7,174ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# [INFO]: Time taken for simulation start : 0.543832 seconds
# [INFO]: Completed setting up the environment...
# 2025-09-02 23:25:44 [7,233ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPreviewSurface.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdUVTexture.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float2.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float3.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float4.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-02 23:25:44 [7,234ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_int.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# ...
# 2025-09-03 03:01:46 s] [Warning] [omni.usd_config.extension] Enable omni.materialx.libs extension to use MaterialX
# 2025-09-03 03:01:46 s] [Warning] [omni.datastore] OmniHub is inaccessible
# 2025-09-03 03:01:46 s] [Warning] [omni.isaac.dynamic_control] omni.isaac.dynamic_control is deprecated as of Isaac Sim 4.5. No action is needed from end-users.
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-Humanoid-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# /home/isaacp/miniconda3/envs/env_isaaclab/lib/python3.10/site-packages/gymnasium/envs/registration.py:636: UserWarning: WARN: Overriding environment Isaac-H1-Velocity-Direct-v0 already in registry.
#   logger.warn(f"Overriding environment {new_spec.id} already in registry.")
# 2025-09-03 03:01:50 [4,452ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
# 2025-09-03 03:01:50 [4,452ms] [Warning] [gpu.foundation.plugin] Skipping unsupported non-NVIDIA GPU: AMD Unknown (RADV RAPHAEL_MENDOCINO)
#
# |---------------------------------------------------------------------------------------------|
# | Driver Version: 550.144.03    | Graphics API: Vulkan
# |=============================================================================================|
# | GPU | Name                             | Active | LDA | GPU Memory | Vendor-ID | LUID       |
# |     |                                  |        |     |            | Device-ID | UUID       |
# |     |                                  |        |     |            | Bus-ID    |            |
# |---------------------------------------------------------------------------------------------|
# | 0   | NVIDIA GeForce RTX 4090          | Yes: 0 |     | 24564   MB | 10de      | 0          |
# |     |                                  |        |     |            | 2684      | e9f2bf62.. |
# |     |                                  |        |     |            | 1         |            |
# |---------------------------------------------------------------------------------------------|
# | 1   | AMD Unknown (RADV RAPHAEL_MEND.. |        |     | 21483   MB | 1002      | 0          |
# |     |                                  |        |     |            | 164e      | 00000000.. |
# |     |                                  |        |     |            | d         |            |
# |=============================================================================================|
# | OS: 22.04.5 LTS (Jammy Jellyfish) ubuntu, Version: 22.04.5, Kernel: 6.8.0-65-generic
# | XServer Vendor: The X.Org Foundation, XServer Version: 12101004 (1.21.1.4)
# | Processor: AMD Ryzen 9 7950X 16-Core Processor
# | Cores: 16 | Logical Cores: 32
# |---------------------------------------------------------------------------------------------|
# | Total Memory (MB): 63426 | Free Memory: 42909
# | Total Page/Swap (MB): 2047 | Free Page/Swap: 2047
# |---------------------------------------------------------------------------------------------|
# 2025-09-03 03:01:51 [5,750ms] [Warning] [gpu.foundation.plugin] IOMMU is enabled.
# 2025-09-03 03:01:51 [5,750ms] [Warning] [gpu.foundation.plugin] Detected IOMMU is enabled. Running CUDA peer-to-peer bandwidth and latency validation.
# Unidirectional P2P=Enabled Bandwidth (P2P Writes) Matrix (GB/s)
#    D\D     0
#      0 912.68
# P2P=Enabled Latency (P2P Writes) Matrix (us)
#    GPU     0
#      0   1.47
#
#    CPU     0
#      0   1.54
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# [INFO]: Parsing configuration from: <class 'isaaclab_tasks.direct.leatherback.leatherback_sumo_ma_stage2.LeatherbackSumoMAStage2EnvCfg'>
# [INFO]: Parsing configuration from: /home/isaacp/sharedrepos/IsaacLab-HARL/source/isaaclab_tasks/isaaclab_tasks/direct/leatherback/agents/harl_happo_adv_cfg.yaml
# choose to use gpu...
# 2025-09-03 03:01:52 [6,258ms] [Warning] [isaaclab.envs.direct_marl_env] Seed not set for the environment. The environment creation may not be deterministic.
# [INFO]: Base environment:
# 	Environment device    : cuda:0
# 	Environment seed      : None
# 	Physics step-size     : 0.005
# 	Rendering step-size   : 0.02
# 	Environment step-size : 0.02
# [INFO]: Time taken for scene creation : 0.338743 seconds
# [INFO]: Scene manager:  <class InteractiveScene>
# 	Number of environments: 100
# 	Environment spacing   : 12
# 	Source prim name      : /World/envs/env_0
# 	Global prim paths     : []
# 	Replicate physics     : True
# [INFO]: Starting the simulation. This may take a few seconds. Please wait...
# 2025-09-03 03:01:53 [7,079ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,079ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,081ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,081ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,134ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,135ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,135ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,135ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,141ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,141ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,142ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,142ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,148ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,148ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# 2025-09-03 03:01:53 [7,148ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'effort_limit'. This parameter will be removed in the future. To set the effort limit, please use 'effort_limit_sim' instead.
# 2025-09-03 03:01:53 [7,149ms] [Warning] [isaaclab.actuators.actuator_pd] The <ImplicitActuatorCfg> object has a value for 'velocity_limit'. Previously, although this value was specified, it was not getting used by implicit actuators. Since this parameter affects the simulation behavior, we continue to not use it. This parameter will be removed in the future. To set the velocity limit, please use 'velocity_limit_sim' instead.
# [INFO]: Time taken for simulation start : 0.569317 seconds
# [INFO]: Completed setting up the environment...
# 2025-09-03 03:01:53 [7,212ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPreviewSurface.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,212ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdUVTexture.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,212ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float2.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float3.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_float4.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_int.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_string.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_normal.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_point.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_vector.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdPrimvarReader_matrix.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# 2025-09-03 03:01:53 [7,213ms] [Warning] [omni.usd] Warning: in GetNodeDiscoveryResults at line 136 of /builds/omniverse/usd-ci/USD/pxr/usd/usdShade/shaderDefUtils.cpp -- Unable to resolve info:sourceAsset </UsdTransform2d.info:mdl:sourceAsset> with value @UsdPreviewSurface.mdl@.
#
# share_observation_space:  {'team_0': Box(-inf, inf, (28,), float32), 'team_1': Box(-inf, inf, (28,), float32)}
# observation_space:  {'team_0': {'robot_0': Box(-inf, inf, (14,), float32), 'robot_1': Box(-inf, inf, (14,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (14,), float32), 'robot_3': Box(-inf, inf, (14,), float32)}}
# action_space:  {'team_0': {'robot_0': Box(-inf, inf, (2,), float32), 'robot_1': Box(-inf, inf, (2,), float32)}, 'team_1': {'robot_2': Box(-inf, inf, (2,), float32), 'robot_3': Box(-inf, inf, (2,), float32)}}
# /home/isaacp/sharedrepos/HARL/harl/runners/on_policy_base_runner_adversarial.py:948: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   state_dict = torch.load(actor_path)
# Playing: 3100200it [02:03, 25064.69it/s]
# {'Episode_Reward/team_0_push_out_reward': 0.018432200224898974,
#  'Episode_Reward/team_1_push_out_reward': -0.019636896532670714,
#  'team0_win_percentage': 0.7434915773353752,
#  'team1_win_percentage': 0.19831546707503828}

# %%
results.keys()
# Out:
# dict_keys([])

# %%
import pickle

pickle.dump(results, open("leatherback_paper_results.pkl", "wb"))

# %%
res = pickle.load(open("leatherback_paper_results.pkl", "rb"))
res['episode_num'].keys()
# Out:
# dict_keys(['ladder', 'leapfrog', 'parallel'])

# %%
import matplotlib.pyplot as plt

    

plt.figure(figsize=(12, 8))
# plt.plot(results["episode_num"]["ladder"], results["team0_win_percentage"]["ladder"], marker='o', label='Ladder Training')
plt.plot(results["episode_num"]["leapfrog"], results["team0_win_percentage"]["leapfrog"], marker='o', label='Leapfrog Training')
plt.plot(results["episode_num"]["parallel"], results["team0_win_percentage"]["parallel"], marker='o', label='Parallel Training')
plt.xlabel("Episode Number")
plt.ylabel("Team 0 Win Percentage")
plt.legend()
plt.show()
